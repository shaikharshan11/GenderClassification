# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\Mohammed Arshan\\Downloads\\archive\\gender_classification_v7.csv")

# %%
data
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
data.long_hair.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data.long_hair.value_counts()
# Out:
# 1    4349
# 0     652
# Name: long_hair, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
data.describe(include='all')
# Out:
#           long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count   5001.000000        5001.000000         5001.000000  5001.000000
# unique          NaN                NaN                 NaN          NaN
# top             NaN                NaN                 NaN          NaN
# freq            NaN                NaN                 NaN          NaN
# mean       0.869626          13.181484            5.946311     0.493901
# std        0.336748           1.107128            0.541268     0.500013
# min        0.000000          11.400000            5.100000     0.000000
# 25%        1.000000          12.200000            5.500000     0.000000
# 50%        1.000000          13.100000            5.900000     0.000000
# 75%        1.000000          14.000000            6.400000     1.000000
# max        1.000000          15.500000            7.100000     1.000000
#
#           nose_long    lips_thin  distance_nose_to_lip_long  gender
# ...

# %%
data.boxplot()
# Out:
# <AxesSubplot: >

# %%
data.plot()
# Out:
# <AxesSubplot: >

# %%
sns.countplot(data.lips_thin)
# Out:
# <AxesSubplot: ylabel='count'>

# %%
plt.scatter(data["forehead_width_cm"], data["forehead_height_cm"])
plt.show()

# %%
sns.regplot(x=data["forehead_height_cm"], y=data["forehead_width_cm"])
plt.xlabel("Forehead Height (cm)")
plt.ylabel("Forehead Width (cm)")
plt.title("Regression Plot")
plt.show()

# %%
sns.jointplot(x=data["forehead_height_cm"], y=data["forehead_width_cm"])
plt.xlabel("Forehead Height (cm)")
plt.ylabel("Forehead Width (cm)")
plt.title("Joint Plot")
plt.show()

# %%
sns.pairplot(data)

# %%
data.corr()
# Out:
# C:\Users\Mohammed Arshan\AppData\Local\Temp\ipykernel_8064\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                            long_hair  forehead_width_cm  forehead_height_cm  \
# long_hair                   1.000000          -0.006530           -0.017233
# forehead_width_cm          -0.006530           1.000000            0.088596
# forehead_height_cm         -0.017233           0.088596            1.000000
# nose_wide                   0.001216           0.251648            0.211655
# nose_long                   0.014432           0.257368            0.194120
# lips_thin                   0.011287           0.258564            0.205441
# distance_nose_to_lip_long  -0.025794           0.251328            0.215292
#
# ...

# %%
sns.heatmap(data.corr())
# Out:
# C:\Users\Mohammed Arshan\AppData\Local\Temp\ipykernel_8064\1794321463.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <AxesSubplot: >

# %%
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
data.tail()
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 4996          0                          0  Female
# 4997          0                          0  Female
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male

# %%
data.shape
# Out:
# (5001, 8)

# %%
data.isnull()
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0         False              False               False      False      False
# 1         False              False               False      False      False
# 2         False              False               False      False      False
# 3         False              False               False      False      False
# 4         False              False               False      False      False
# ...         ...                ...                 ...        ...        ...
# 4996      False              False               False      False      False
# 4997      False              False               False      False      False
# 4998      False              False               False      False      False
# 4999      False              False               False      False      False
# 5000      False              False               False      False      False
#
# ...

# %%
data.isnull().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
data['gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['gender'] = data['gender'].map({'Male':1, 'Female':0}).astype('int')

# %%
data['gender'].unique()
# Out:
# array([1, 0])

# %%
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1       1
# 1          1                          0       0
# 2          1                          1       1
# 3          1                          1       1
# 4          0                          0       0

# %%
X = data.drop('gender', axis = 1)

# %%
y = data['gender']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 4996    0
# 4997    0
# 4998    0
# 4999    0
# 5000    1
# Name: gender, Length: 5001, dtype: int32

# %%
cols = ['forehead_width_cm','forehead_height_cm']

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X[cols] = st.fit_transform(X[cols])

# %%
X
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1          -1.247933            0.283971          1          0
# 1             0           0.739389           -1.009418          0          0
# 2             0          -1.247933            0.653511          1          1
# 3             0           1.100720            0.283971          0          1
# 4             1           0.287725           -0.085568          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1           0.378057           -1.563727          0          0
# 4997          1          -1.157600           -1.009418          0          0
# 4998          1          -0.254272           -0.455108          0          0
# 4999          1           0.016726            0.468741          0          0
# 5000          1           2.004048           -1.009418          1          1
#
#       lips_thin  distance_nose_to_lip_long
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
model_df={}
def model_val(model,X,y):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print(f"{model} accuracy is {accuracy_score(y_test,y_pred)}")

    score = cross_val_score(model,X,y,cv=5)
    print(f"{model} Average score is {np.mean(score)}")
    model_df[model] = round(np.mean(score)*100,2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model_val(model,X,y)
# Out:
# LogisticRegression() accuracy is 0.961038961038961
# LogisticRegression() Average score is 0.9680077922077922

# %%
model_df
# Out:
# {LogisticRegression(): 96.8,
#  SVC(): 97.4,
#  DecisionTreeClassifier(): 96.44,
#  RandomForestClassifier(): 97.04,
#  GradientBoostingClassifier(): 97.44}

# %%
from sklearn import svm
model = svm.SVC()
model_val(model,X,y)
# Out:
# SVC() accuracy is 0.968031968031968
# SVC() Average score is 0.9740073926073926

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model_val(model,X,y)
# Out:
# DecisionTreeClassifier() accuracy is 0.9530469530469531
# DecisionTreeClassifier() Average score is 0.9644093906093906

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model_val(model,X,y)
# Out:
# RandomForestClassifier() accuracy is 0.962037962037962
# RandomForestClassifier() Average score is 0.9704085914085914

# %%
from sklearn.ensemble import GradientBoostingClassifier
model =GradientBoostingClassifier()
model_val(model,X,y)
# Out:
# GradientBoostingClassifier() accuracy is 0.967032967032967
# GradientBoostingClassifier() Average score is 0.9744065934065933

# %%
X = data.drop('gender',axis=1)
y = data['gender']

# %%
rf = RandomForestClassifier(n_estimators=270, min_samples_split=5, min_samples_leaf=5, max_features='sqrt', max_depth=5)

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=5,
#                        n_estimators=270)

# %%
import joblib

# %%
joblib.dump(rf,'gender_predict')
# Out:
# ['gender_predict']

# %%
model = joblib.load('gender_predict')

# %%
df = pd.DataFrame({'long_hair':1, 'forehead_width_cm':14, 'forehead_height_cm':5.2, 'nose_wide':0, 'nose_long':0, 'lips_thin':1, 'distance_nose_to_lip_long':0},index=[0])

# %%
df
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1                 14                 5.2          0          0
#
#    lips_thin  distance_nose_to_lip_long
# 0          1                          0

# %%
result = model.predict(df)

# %%
if result==1:
    print("Gender is male")
else:
    print("Gender is female")
# Out:
# Gender is female
